# %%
# Step:1 import libraries
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
# Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# scikit
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %%
# import dataset
df = sns.load_dataset('tips')

# %%
# Data preprocessing
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['day'] = le.fit_transform(df['day'])
df['time'] = le.fit_transform(df['time'])

# %%
# convert 'tip' to binary variable, 1 if the tip is above $2, else 0
df['tip'] = (df['tip'] > 2).astype(int)

X = df.drop('tip', axis=1)
y = df['tip']

# %%
# Scaler the data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train test split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size= 0.2, random_state= 42)

# %%
# Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape= [X_train.shape[1]]),   #input layer
    tf.keras.layers.Dense(8, activation= 'relu'),    #hidden layer
    tf.keras.layers.Dense(1, activation= 'sigmoid')  #output layer
])
# Out:
# d:\AiEngineer\Deep_Learning\TensorFlow\TF_env\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# %%time
# Compile the model
model.compile(
    optimizer = 'adam', loss= 'binary_crossentropy', metrics=['accuracy']
)

# Train the model
model.fit(X_train, y_train, epochs= 5, batch_size=8, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test Loss:' , loss)
print('Test Accuracy:' , accuracy)
# Out:
# Epoch 1/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7128 - loss: 0.5966
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7077 - loss: 0.5842
# Epoch 3/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7231 - loss: 0.5751
# Epoch 4/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7231 - loss: 0.5680
# Epoch 5/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7179 - loss: 0.5624
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5510 - loss: 0.6942
# Test Loss: 0.6942426562309265
# Test Accuracy: 0.5510203838348389
# CPU times: total: 1.73 s
# Wall time: 1.52 s
